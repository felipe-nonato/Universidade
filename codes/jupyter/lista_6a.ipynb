# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>ESTATÍSTICA APLICADA</center>
# <center>LISTA 06a</center>
# <center>ALUNO: Luís Felipe Ferreira Tavares Nonato</center>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 1
# </div>

# %% [markdown]
# **a** - Alturas de balões de ar quente - _quantitativo_ (melhor representado com números<br>
# **b** - Capacidades de carga de caminhonetes: _quantitativo_ (melhor representado com números)<br>
# **c** - Cores dos olhos de modelos: _qualitativo_ (melhor representado por meio de palavras)<br>
# **d** - Números de identidade de estudantes: _quantitativo_ (melhor representado com números)<br>
# **e** - Respostas em uma pesquisa de opinião: _qualitativo_ (melhor representado por meio de palavras)

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 2
# </div>

# %%
import pandas as pd
import numpy as np

# %%
DadosCalouros = {
    
'Sexo' : ['F','M','F','F','M','M','F','F','F','M','F','M','M','M',
          'M','M','F','F','M','M','F','F','M','M','F','F','M','M',
          'F','F','F','M','M','F','M','M','F','M','F','F','F','M'],
    
'Predileta' : ['H','M','P','H','C','H','M','P','H','C','P','M','G','G',
               'M','M','P','G','G','P','M','G','H','M','P','G','C','H',
               'M','P','M','G','H','M','P','G','M','P','M','M','P','M'], 
    
'Nota' : [5,8,8,6,5,6,8,4,2,6,8,2,4,9,
          7,1,8,5,9,5,8,6,3,5,5,5,7,4,
          7,7,6,6,9,8,5,6,7,5,5,5,9,8]
    
}

dfCalouros = pd.DataFrame(DadosCalouros)
dfCalouros
# Out:
#    Sexo Predileta  Nota
# 0     F         H     5
# 1     M         M     8
# 2     F         P     8
# 3     F         H     6
# 4     M         C     5
# 5     M         H     6
# 6     F         M     8
# 7     F         P     4
# 8     F         H     2
# 9     M         C     6
# 10    F         P     8
# 11    M         M     2
# 12    M         G     4
# 13    M         G     9
# 14    M         M     7
# 15    M         M     1
# 16    F         P     8
# 17    F         G     5
# 18    M         G     9
# 19    M         P     5
# 20    F         M     8
# 21    F         G     6
# 22    M         H     3
# 23    M         M     5
# 24    F         P     5
# 25    F         G     5
# 26    M         C     7
# 27    M         H     4
# 28    F         M     7
# 29    F         P     7
# 30    F         M     6
# 31    M         G     6
# 32    M         H     9
# 33    F         M     8
# 34    M         P     5
# 35    M         G     6
# 36    F         M     7
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# a)
# </div>

# %% [markdown]
# **Sexo e Predileta:** _qualitativo nominal_ (melhor representado com palavras)<br>
# **Nota:** _quantitativo discreto_ (melhor representado com números)

# %% [markdown]
# <div class="alert alert-block alert-info">
# b)
# </div>

# %%
dfCalouros[['Sexo','Predileta','Nota']] = dfCalouros[['Sexo','Predileta','Nota']].astype('category')

# %%
dfCalouros['Sexo'].value_counts(normalize=True)*100
# Out:
# F    50.0
# M    50.0
# Name: Sexo, dtype: float64

# %%
dfCalouros['Predileta'].value_counts(normalize=True)*100
# Out:
# M    33.333333
# P    23.809524
# G    19.047619
# H    16.666667
# C     7.142857
# Name: Predileta, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 3
# </div>

# %%
dfUFSC = {
    'PAP':['Não','Não','Sim','Não','Sim','Sim','Não','Sim','Sim','Sim',
           'Não','Sim','Não','Não','Não','Não','Sim','Não','Não','Sim',
           'Sim','Sim','Não','Não','Não','Sim','Sim','Não','Sim','Não',
           'Sim','Sim','Sim','Sim','Sim','Sim','Sim','Sim','Sim','Sim'],
    
    'GI':['segundo grau','segundo grau','primeiro grau','primeiro grau','segundo grau','nenhum grau','segundo grau','segundo grau','segundo grau','primeiro grau',
          'primeiro grau','nenhum grau','primeiro grau','primeiro grau','segundo grau','primeiro grau','segundo grau','segundo grau','segundo grau','segundo grau',
          'segundo grau','segundo grau','segundo grau','primeiro grau','primeiro grau','segundo grau','nenhum grau','segundo grau','primeiro grau','segundo grau',
          'segundo grau','primeiro grau','segundo grau','nenhum grau','nenhum grau','nenhum grau','segundo grau','segundo grau','segundo grau','segundo grau'],
    
    'RES':[4,4,4,5,4,1,2,3,6,4,
           6,4,4,6,3,5,3,4,4,4,
           5,5,5,4,8,4,5,3,4,5,
           5,2,5,2,6,8,3,5,5,3],
    
    'Renda':[10.3,15.4,9.6,5.5,9,2.4,4.1,8.4,10.3,4.6,
             18.6,7.1,12.9,8.4,19.3,10.4,8.9,12.9,5.1,12.2,
             5.9,12.9,7.7,1.1,7.5,5.8,7.2,8.6,5.1,2.6,
             7.7,2.4,4.8,2.1,4,12.5,6.8,3.9,9,10.9]
}
    
dfUFSC = pd.DataFrame(dfUFSC)
dfUFSC
# Out:
#     PAP             GI  RES  Renda
# 0   Não   segundo grau    4   10.3
# 1   Não   segundo grau    4   15.4
# 2   Sim  primeiro grau    4    9.6
# 3   Não  primeiro grau    5    5.5
# 4   Sim   segundo grau    4    9.0
# 5   Sim    nenhum grau    1    2.4
# 6   Não   segundo grau    2    4.1
# 7   Sim   segundo grau    3    8.4
# 8   Sim   segundo grau    6   10.3
# 9   Sim  primeiro grau    4    4.6
# 10  Não  primeiro grau    6   18.6
# 11  Sim    nenhum grau    4    7.1
# 12  Não  primeiro grau    4   12.9
# 13  Não  primeiro grau    6    8.4
# 14  Não   segundo grau    3   19.3
# 15  Não  primeiro grau    5   10.4
# 16  Sim   segundo grau    3    8.9
# 17  Não   segundo grau    4   12.9
# 18  Não   segundo grau    4    5.1
# 19  Sim   segundo grau    4   12.2
# 20  Sim   segundo grau    5    5.9
# 21  Sim   segundo grau    5   12.9
# 22  Não   segundo grau    5    7.7
# 23  Não  primeiro grau    4    1.1
# 24  Não  primeiro grau    8    7.5
# 25  Sim   segundo grau    4    5.8
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# a)
# </div>

# %% [markdown]
# **PAP:** _qualitativo nominal_<br>
# **GI:** _qualitativo ordinal_<br>
# **RES:** _quantitativo discreto_<br>
# **Renda:** _quantitativo continuo_

# %% [markdown]
# <div class="alert alert-block alert-info">
# b)
# </div>

# %%
dfUFSC[['PAP','GI','RES','Renda']] = dfUFSC[['PAP','GI','RES','Renda']].astype('category')

# %%
dfUFSC['PAP'].value_counts(normalize=True)*100
# Out:
# Sim    60.0
# Não    40.0
# Name: PAP, dtype: float64

# %%
dfUFSC['GI'].value_counts(normalize=True)*100
# Out:
# segundo grau     57.5
# primeiro grau    27.5
# nenhum grau      15.0
# Name: GI, dtype: float64
