# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>ESTATÍSTICA APLICADA</center>
# <center>LISTA 6b</center>
# <center>ALUNO: Luís Felipe Ferreira Tavares Nonato</center>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfDados1 = pd.read_csv('/home/lipe/Documentos/repositorios/Faculdade/codes/jupyter/listas/6b/dados1.csv',sep=';')

dfDados2 = pd.read_csv('/home/lipe/Documentos/repositorios/Faculdade/codes/jupyter/listas/6b/dados2.csv',sep=';')

dfDados3 = pd.read_excel('/home/lipe/Documentos/repositorios/Faculdade/codes/jupyter/listas/6b/dados3.xls')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 1
# </div>

# %% [markdown]
# Tratando os dados com a função `transpose()` que transforma as linhas em colunas, e a função `stack()` que empilhas os dados em apenas uma coluna.

# %%
pd.DataFrame(dfDados1.transpose().reset_index().stack()).value_counts(ascending=True).plot.bar(title="Ocorrências das notas")
plt.xlabel('Notas')
plt.ylabel('Ocorrências')
# Out:
# Text(0, 0.5, 'Ocorrências')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 2
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# a)
# </div>

# %% [markdown]
# **Bairro:** _qualitativa nominal_ <br>
# **Tipo:** _qualitativa nominal_ <br>
# **N de quartos:** _quantitativo discreto_ <br>
# **Preço(mil):** _quantitativo discreto_

# %% [markdown]
# <div class="alert alert-block alert-info">
# b / c)
# </div>

# %%
dfDados2['Bairro'].value_counts(normalize=True)*100
# Out:
# Barra          14.814815
# Tijuca         11.111111
# Copacabana     11.111111
# Laranjeiras     7.407407
# Flamengo        7.407407
# Leblon          7.407407
# São Conrado     3.703704
# Recreio         3.703704
# Maracanã        3.703704
# Ipanema         3.703704
# Lagoa           3.703704
# Botafogo        3.703704
# Jacarepaguá     3.703704
# Gávea           3.703704
# Centro          3.703704
# Catete          3.703704
# Vila Isabel     3.703704
# Name: Bairro, dtype: float64

# %%
(dfDados2['Bairro'].value_counts(normalize=True,ascending=True)*100).plot.barh()
plt.xlabel('Frequência')
plt.ylabel('Bairro')
# Out:
# Text(0, 0.5, 'Bairro')

# %%
dfDados2['Tipo'].value_counts(normalize=True)*100
# Out:
# Apto.    74.074074
# Cobt.    11.111111
# Sala      7.407407
# Casa      7.407407
# Name: Tipo, dtype: float64

# %%
(dfDados2['Tipo'].value_counts(normalize=True)*100).plot.pie()
plt.xlabel('Tipo')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
dfDados2['N de quartos'].value_counts()
# Out:
# 2      9
# 3      8
# >=4    6
# 1      3
# 0      1
# Name: N de quartos, dtype: int64

# %%
(dfDados2['N de quartos'].value_counts(ascending=True)).plot.bar()
plt.xlabel('Número de quartos')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados2['Preço (mil)'].value_counts()
# Out:
# 290    2
# 210    2
# 200    2
# 320    1
# 370    1
# 430    1
# 338    1
# 260    1
# 340    1
# 219    1
# 220    1
# 254    1
# 276    1
# 165    1
# 240    1
# 180    1
# 330    1
# 280    1
# 110    1
# 250    1
# 270    1
# 90     1
# 158    1
# 230    1
# Name: Preço (mil), dtype: int64

# %%
(dfDados2['Preço (mil)'].value_counts(ascending=True)).plot.pie()
plt.xlabel('Frequência')
plt.ylabel('Preço (mil)')
# Out:
# Text(0, 0.5, 'Preço (mil)')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Questão 3
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# a)
# </div>

# %% [markdown]
# **Turma:** _qualitativo nominal_ <br>
# **Sexo:** _qualitativo nominal_ <br>
# **Idade:** _quantitativo continuo_ <br>
# **Alt:** _quantitativo continuo_ <br>
# **Peso:** _quantitativo continuo_ <br>
# **Filhos:** _quantitativo discreto_ <br>
# **Fuma:**  _qualitativo nominal_ <br>
# **Tolr:** _qualitativo ordinal_ <br>
# **Exerc:** _quantitativo continuo_ <br>
# **Cine:** _quantitativo discreto_ <br>
# **OpCine:** _qualitativo ordinal_ <br>
# **TV:** _quantitativo continuo_ <br>
# **OpTV:** _qualitativo ordinal_

# %% [markdown]
# <div class="alert alert-block alert-info">
# b / c)
# </div>

# %%
dfDados3['Turma'].value_counts(normalize=True)*100
# Out:
# A    52.0
# B    48.0
# Name: Turma, dtype: float64

# %%
(dfDados3['Turma'].value_counts(normalize=True, ascending=True)*100).plot.bar()
plt.xlabel('Turma')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Sexo'].value_counts(normalize=True)*100
# Out:
# F    74.0
# M    26.0
# Name: Sexo, dtype: float64

# %%
(dfDados3['Sexo'].value_counts(normalize=True, ascending=True)*100).plot.bar()
plt.xlabel('Sexo')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Idade'].value_counts()
# Out:
# 18    22
# 17     9
# 19     7
# 20     4
# 21     3
# 25     2
# 23     2
# 24     1
# Name: Idade, dtype: int64

# %%
dfDados3['Idade'].value_counts(ascending=True).plot.bar()
plt.xlabel('Idade')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Alt'].value_counts()
# Out:
# 1.70    6
# 1.60    5
# 1.65    4
# 1.85    3
# 1.62    3
# 1.55    3
# 1.76    2
# 1.64    2
# 1.73    2
# 1.69    2
# 1.80    2
# 1.68    2
# 1.57    2
# 1.45    1
# 1.67    1
# 1.54    1
# 1.71    1
# 1.61    1
# 1.63    1
# 1.82    1
# 1.78    1
# 1.66    1
# 1.72    1
# 1.58    1
# 1.83    1
# Name: Alt, dtype: int64

# %%
dfDados3['Alt'].value_counts(ascending=True).plot.bar()
plt.xlabel('Altura')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Peso'].value_counts()
# Out:
# 55.0    4
# 58.0    4
# 60.0    3
# 50.0    2
# 47.0    2
# 52.0    2
# 49.0    2
# 54.5    2
# 73.0    2
# 60.5    1
# 56.0    1
# 59.0    1
# 95.0    1
# 87.0    1
# 57.0    1
# 84.0    1
# 44.0    1
# 75.0    1
# 71.0    1
# 63.0    1
# 49.2    1
# 51.6    1
# 48.0    1
# 58.5    1
# 52.5    1
# 85.2    1
# 66.0    1
# 47.4    1
# 63.5    1
# 68.5    1
# 54.0    1
# 70.0    1
# 57.8    1
# 80.9    1
# 72.8    1
# 86.0    1
# Name: Peso, dtype: int64

# %%
dfDados3['Peso'].value_counts(ascending=True).plot.bar()
plt.xlabel('Peso')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Filhos'].value_counts()
# Out:
# 1    28
# 2    14
# 3     6
# 4     1
# 7     1
# Name: Filhos, dtype: int64

# %%
dfDados3['Filhos'].value_counts(ascending=True).plot.bar()
plt.xlabel('Filhos')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['Fuma'].value_counts(normalize=True)*100
# Out:
# NAO    88.0
# SIM    12.0
# Name: Fuma, dtype: float64

# %%
(dfDados3['Fuma'].value_counts(normalize=True, ascending=True)*100).plot.pie()
# Out:
# <AxesSubplot:ylabel='Fuma'>

# %%
dfDados3['Toler'].value_counts(normalize=True)*100
# Out:
# P    42.0
# M    38.0
# I    20.0
# Name: Toler, dtype: float64

# %%
(dfDados3['Toler'].value_counts(normalize=True, ascending=True)*100).plot.pie()
plt.ylabel('Tolerância ao Cigarro')
plt.xlabel('(I) indiferente, (P) pouco incomoda e (M) incomoda muito')
# Out:
# Text(0.5, 0, '(I) indiferente, (P) pouco incomoda e (M) incomoda muito')

# %%
dfDados3['Exerc'].value_counts(normalize=True)*100
# Out:
# 0     16.0
# 5     16.0
# 2     16.0
# 3     12.0
# 7     10.0
# 4      8.0
# 6      6.0
# 8      6.0
# 1      6.0
# 10     4.0
# Name: Exerc, dtype: float64

# %%
(dfDados3['Exerc'].value_counts(normalize=True, ascending=True)*100).plot.pie()
plt.ylabel('')
plt.xlabel('Número de Exercicios na semana')
# Out:
# Text(0.5, 0, 'Número de Exercicios na semana')

# %%
dfDados3['Cine'].value_counts()
# Out:
# 1    21
# 2    18
# 4     4
# 3     3
# 0     3
# 5     1
# Name: Cine, dtype: int64

# %%
dfDados3['Filhos'].value_counts(ascending=True).plot.bar()
plt.xlabel('Número de vezes que vai ao cinema na semana')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['OpCine'].value_counts(normalize=True)*100
# Out:
# B    64.0
# M    36.0
# Name: OpCine, dtype: float64

# %%
(dfDados3['OpCine'].value_counts(normalize=True)*100).plot.bar()
plt.xlabel('Opinião sobre as salas')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['TV'].value_counts()
# Out:
# 10    11
# 5      7
# 14     5
# 2      4
# 12     4
# 20     3
# 8      3
# 25     2
# 7      2
# 16     1
# 28     1
# 6      1
# 4      1
# 0      1
# 18     1
# 30     1
# 15     1
# 3      1
# Name: TV, dtype: int64

# %%
dfDados3['TV'].value_counts(ascending=True).plot.bar()
plt.xlabel('tempo de TV por semana, em horas')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
dfDados3['OpTV'].value_counts(normalize=True)*100
# Out:
# R    78.0
# N    14.0
# B     6.0
# M     2.0
# Name: OpTV, dtype: float64

# %%
(dfDados3['OpTV'].value_counts(normalize=True, ascending=True)*100).plot.pie()
plt.xlabel('Opinião sobre a qualidade da programação na TV, sendo (R)ruim, (M) média, (B) boa e (N) não sabe')
# Out:
# Text(0.5, 0, 'Opinião sobre a qualidade da programação na TV, sendo (R)ruim, (M) média, (B) boa e (N) não sabe')
